# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../out/orca/data.csv", delimiter=";")

# %%
ax = df.plot(figsize=(20,10), legend = False, x="threads")
ax.set_ylabel("Time (s)")
ax.set_xlabel("Threads")
# ax.set_xticks(range(1, 129, 10))
# plt.xscale("log", basex=2)
plt.show()

# %%
df2 = pd.read_csv("../out/teen/data.csv", delimiter=";")

# %%
ax2 = df2.plot(figsize=(20,10), legend = False, x="threads")
ax2.set_ylabel("Time (s)")
ax2.set_xlabel("Threads")
ax2.set_xticks(range(1,33))
plt.show()

# %%
df["speedup"] = 125/df["time"]
df.tail()
# Out:
#          name   time  threads    speedup
# 123  orca_124   3.73      124  33.512064
# 124  orca_125  10.21      125  12.242899
# 125  orca_126   3.68      126  33.967391
# 126  orca_127   3.64      127  34.340659
# 127  orca_128   3.54      128  35.310734

# %%
df2["speedup"] = 168/df2["time"]
df2.tail()
# Out:
#        name   time  threads    speedup
# 27  teen_28  13.87       28  12.112473
# 28  teen_29  12.78       29  13.145540
# 29  teen_30  22.49       30   7.469987
# 30  teen_31  22.05       31   7.619048
# 31  teen_32  11.99       32  14.011676

# %%
ax3 = df.plot(figsize=(20,10), legend = False, y="speedup", x="threads")
ax3.set_ylabel("Speedup")
ax3.set_xlabel("Threads")
plt.show()

# %%
ax4 = df2.plot(figsize=(20,10), legend = False, y="speedup", x="threads")
ax4.set_ylabel("Speedup")
ax4.set_xlabel("Threads")
# ax2.set_xticks(range(1,33))
plt.show()

# %%
df["speedup"].max()
# Out:
# 35.31073446327684

# %%
df2["speedup"].max()
# Out:
# 14.011676396997498

# %%
df["time"].min()
# Out:
# 3.54

# %%
df2["time"].min()
# Out:
# 11.99
